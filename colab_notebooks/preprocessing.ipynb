# %%
#how to run .py files in a notebook
#https://rafat-joy99.medium.com/how-to-run-py-files-on-google-colab-46af2831e166#:~:text=Python%20script%20files%20can%20also,or%20open%20an%20existing%20one.

# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#preprocessing 1/7
# !python /content/drive/MyDrive/DLH_Team_78/our_code/preprocessing_reduce_outputs.py
# Out:
# -----------------------------------------
# Load item definitions
# URINE_OUTPUT
# 4397             urine out other
# 4402     urine out straight cath
# 4416                 urine flush
# 4428             cath lab output
# 4436                cath lab out
#                   ...
# 11905              straight cath
# 12182               ed urine out
# 12293                   or urine
# 12297                 pacu urine
# 12298                   cath lab
# Name: LABEL, Length: 99, dtype: object
# -----------------------------------------
# Loading Output Events
# Remove admission and discharge days (since data on urine output is incomplete)
# Load ICU stays...

# %%
#preprocessing 2/7
# !python /content/drive/MyDrive/DLH_Team_78/our_code/preprocessing_reduce_charts.py
# Out:
# -----------------------------------------
# Load item definitions
# GCS_EYE_OPENING
#        ITEMID  ... UNITNAME
# 448       184  ...      NaN
# 9679   227011  ...      NaN
# 11494  220739  ...      NaN
# 12481  226756  ...      NaN
#
# [4 rows x 3 columns]
# GCS_VERBAL_RESPONSE
#        ITEMID  ... UNITNAME
# 1491      723  ...      NaN
# 9682   227014  ...      NaN
# 12037  223900  ...      NaN
# 12483  226758  ...      NaN
#
# [4 rows x 3 columns]
# GCS_MOTOR_RESPONSE
#        ITEMID  ... UNITNAME
# 681       454  ...      NaN
# 9680   227012  ...      NaN
# 12038  223901  ...      NaN
# 12482  226757  ...      NaN
#
# [4 rows x 3 columns]
# GCS_TOTAL
#        ITEMID  ... UNITNAME
# 462       198  ...      NaN
# 12480  226755  ...     None
#
# [2 rows x 3 columns]
# DIASTOLIC_BP
#        ITEMID  ... UNITNAME
# 4633     8364  ...      NaN
# 4637     8368  ...      NaN
# 4709     8440  ...      NaN
# 4710     8441  ...      NaN
# 4759     8502  ...      NaN
# ...

# %%
#preprocessing 3/7
# !python /content/drive/MyDrive/DLH_Team_78/our_code/preprocessing_merge_charts_outputs.py
# Out:
# Loading chart events...
# -----------------------------------------
# Compute BMI and GCS total...
# -----------------------------------------
# Loading output events...
# -----------------------------------------
# Create categorical variable...
# -----------------------------------------
# Save...
# -----------------------------------------
# Save data for logistic regression...

# %%
#PROBLEM HERE FIXED, I edited line 185 from pd.set_option('precision', 1) to pd.set_option('display.precision', 1)
#preprocessing 4/7
# !python /content/drive/MyDrive/DLH_Team_78/our_code/preprocessing_ICU_PAT_ADMIT.py
# Out:
# Load ICU stays...
# -----------------------------------------
# Load patients...
# -----------------------------------------
# Load admissions...
# -----------------------------------------
# Load services...
# -----------------------------------------
# Link icustays and patients tables...
# Compute number of recent admissions...
#   0% 0/43126 [00:00<?, ?it/s]/usr/local/lib/python3.9/dist-packages/tqdm/std.py:1178: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for obj in iterable:
# 100% 43126/43126 [01:00<00:00, 715.89it/s]
# -----------------------------------------
# Link icu_pat and admissions tables...
# SUBJECT_ID                  0
# HADM_ID                     0
# ICUSTAY_ID                  0
# INTIME                      0
# OUTTIME                     0
# LOS                         0
# ...

# %%
#preprocessing 5/7
# !python /content/drive/MyDrive/DLH_Team_78/our_code/preprocessing_DIAGNOSES_PROCEDURES.py
# Out:
# Loading icu_pat...
# -----------------------------------------
# Load admissions...
# -----------------------------------------
# Load diagnoses and procedures...
# -----------------------------------------
# Link diagnoses/procedures and admissions tables...
# Link diagnoses/procedures and icu_pat tables...
# Drop duplicates...
# Map rare codes to OTHER...
# -----------------------------------------
# Save...

# %%
#preprocessing 6/7
# !python /content/drive/MyDrive/DLH_Team_78/our_code/preprocessing_CHARTS_PRESCRIPTIONS.py
# Out:
# Loading icu_pat...
# -----------------------------------------
# Load charts and outputs...
# -----------------------------------------
# Load prescriptions...
# -----------------------------------------
# Link charts/outputs and icu_pat tables...
# Drop duplicates...
# Map rare codes to OTHER...
# -----------------------------------------
# Save...

# %%
#preprocessing 7/7
# !python /content/drive/MyDrive/DLH_Team_78/our_code/preprocessing_create_arrays.py
# Out:
# Loading icu_pat...
# Loading diagnoses/procedures...
# Loading charts/prescriptions...
# -----------------------------------------
# Create static array...
# Create label array...
# Create diagnoses/procedures and charts/prescriptions array...
# max_count 552
# Reindex df...
# done
# max_count 392
# Reindex df...
# done
# -----------------------------------------
# Split data into train/validate/test...
# Get patients corresponding to test ids
# -----------------------------------------
# Save...
