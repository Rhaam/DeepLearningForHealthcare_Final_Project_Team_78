# %%
#how to run .py files in a notebook
#https://rafat-joy99.medium.com/how-to-run-py-files-on-google-colab-46af2831e166#:~:text=Python%20script%20files%20can%20also,or%20open%20an%20existing%20one.

# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install torchdiffeq
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# If you get the error below, run !pip install torchdiffeq as shown in the line above
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/DLH_Team_78/our_code/modules.py", line 13, in <module>
#     from modules_ode import *
#   File "/content/drive/MyDrive/DLH_Team_78/our_code/modules_ode.py", line 8, in <module>
#     from torchdiffeq import odeint, odeint_adjoint
# ModuleNotFoundError: No module named 'torchdiffeq'

# %%
# !python /content/drive/MyDrive/DLH_Team_78/our_code/modules.py

# %%
# !python /content/drive/MyDrive/DLH_Team_78/our_code/modules_ode.py

# %%
# !python /content/drive/MyDrive/DLH_Team_78/our_code/data_load.py
#The section of the code that creates the required files was commented out initially in the original codebase, resulting in an error of 'files not found' 
# for the above file run. We could not understand why that was done, so we uncommented those lines after which this file ran successfully.
# Out:
# Load data...

# %%
#train.py
# !python /content/drive/MyDrive/DLH_Team_78/our_code/train.py
# Out:
# Load data...
# -----------------------------------------
# Train...
#   0% 0/10 [00:00<?, ?it/s]
#   0% 0/318 [00:00<?, ?it/s]/usr/local/lib/python3.9/dist-packages/torchdiffeq/_impl/misc.py:11: UserWarning: Euler: Unexpected arguments {'max_num_steps': 1000}
#   warnings.warn('{}: Unexpected arguments {}'.format(solver.__class__.__name__, unused_kwargs))
#
#   0% 1/318 [00:01<07:09,  1.35s/it]
#   1% 2/318 [00:01<03:30,  1.50it/s]
#   1% 3/318 [00:01<02:21,  2.22it/s]
#   1% 4/318 [00:01<01:51,  2.81it/s]
#   2% 5/318 [00:02<01:31,  3.43it/s]
#   2% 6/318 [00:02<01:20,  3.86it/s]
#   2% 7/318 [00:02<01:14,  4.16it/s]
#   3% 8/318 [00:02<01:07,  4.58it/s]
#   3% 9/318 [00:02<01:04,  4.75it/s]
#   3% 10/318 [00:03<01:03,  4.88it/s]
#   3% 11/318 [00:03<01:00,  5.10it/s]
#   4% 12/318 [00:03<00:58,  5.21it/s]
#   4% 13/318 [00:03<00:57,  5.32it/s]
#   4% 14/318 [00:03<01:00,  5.03it/s]
#   5% 15/318 [00:03<00:55,  5.42it/s]
#   5% 16/318 [00:04<00:57,  5.27it/s]
# ...

# %%
# !python /content/drive/MyDrive/DLH_Team_78/our_code/test.py
